# %%
from sympy import *
from sympy.plotting import plot3d
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x, y = symbols('x, y')

# %% [markdown]
# ## 1.

# %%
f = sin(sqrt(x ** 2 + y ** 2))
f
# Out:
#    /   _________\
#    |  /  2    2 |
# sin\\/  x  + y  /

# %%
plot3d(f)

# %% [markdown]
# ## 2.

# %%
f = exp(-0.9 * (x**2 + 0.5 * (x - y)**2))
f
# Out:
#         2               2
#  - 0.9*x  - 0.45*(x - y)
# e

# %%
plot3d(f, (x, -3, 3), (y, -3, 3))

# %% [markdown]
# ## 3.

# %%
f = x * cos(y)
f
# Out:
# x*cos(y)

# %%
plot3d(f)

# %%
f2 = x**2 + y**2 - 1
f2
# Out:
#  2    2
# x  + y  - 1

# %%
plot3d(f2)
